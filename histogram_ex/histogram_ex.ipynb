# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import csv

# %%
filename = "number_of_days.csv"

# %%
# !ls
# Out:
# number_of_days.csv  sample_data

# %%
data = []
with open(filename, mode = 'r') as f:
    data = np.array(list(csv.reader(f)))

# %%
data.shape = (1171,)

# %%
data
# Out:
# array(['17', '324', '2', ..., '0', '0', '0'], dtype='<U3')

# %%
data = np.array([int(i) for i in data])

# %%
plt.hist(data)
# Out:
# (array([408., 171., 102., 128.,  81.,  12.,  58.,  77.,  58.,  76.]),
#  array([  0. ,  75.7, 151.4, 227.1, 302.8, 378.5, 454.2, 529.9, 605.6,
#         681.3, 757. ]),
#  <BarContainer object of 10 artists>)

# %%
df = pd.DataFrame(data, columns=['num_days'])

# %%
df[df['num_days'] < 20].hist()
# Out:
# array([[<Axes: title={'center': 'num_days'}>]], dtype=object)

# %%
lt20 = df[df['num_days'] < 18]

# %%
plt.hist(lt20, bins=20, range=(0,18))
# Out:
# (array([21., 83., 30.,  4.,  7.,  0.,  0.,  7.,  1.,  0.,  2.,  6., 10.,
#          3.,  5., 34.,  7.,  3.,  8.,  0.]),
#  array([ 0. ,  0.9,  1.8,  2.7,  3.6,  4.5,  5.4,  6.3,  7.2,  8.1,  9. ,
#          9.9, 10.8, 11.7, 12.6, 13.5, 14.4, 15.3, 16.2, 17.1, 18. ]),
#  <BarContainer object of 20 artists>)
